# %% [markdown]
# ## Измерения для лабораторной работы 4.7.3

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# >### Определение разрешённых направлений поляроидов

# %%
display(df[df.columns[0:2]])
# Out:
#    $\phi_1$  $\phi_2$
# 0       170        50

# %% [markdown]
# >### Определение угла Брюстера для эбонита

# %%
display(df[df.columns[3:7]])
# Out:
#    ${\phi_{\text{Б}}}_1$  ${\phi_{\text{Б}}}_2$  ${\phi_{\text{БС}}}_1$  \
# 0                    146                     87                     145
#
#    ${\phi_{\text{БС}}}_2$
# 0                      87

# %% [markdown]
# >### Исследование стопы

# %%
display(df[df.columns[9:11]])
# Out:
#    $\phi_1 $  $\phi_2 $
# 0         75        125

# %% [markdown]
# >### Определение главных плоскостей двоякопреломляющих пластин

# %%
display(df[df.columns[12:14]])
# Out:
#    $\phi_{\text{П1}}$  $\phi_{\text{П2}}$
# 0                  56                  74

# %% [markdown]
# >### Определение направления вращения светового вектора в эллиптически поляризованной волне

# %%
display(df[df.columns[15:17]])
# Out:
#       серия 1  серия 2
# 0  скрещенный      -45
